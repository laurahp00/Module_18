# %%
import os
from os import chdir
from glob import glob
import pandas as pd
import csv 
import numpy as np

# %%
# Create a DataFrame
file1 = "JC-202010-citibike-tripdata.csv"
file2 = "JC-202011-citibike-tripdata.csv"
file3 = "JC-202012-citibike-tripdata.csv"

october_df = pd.read_csv(file1)
november_df = pd.read_csv(file2)
december_df = pd.read_csv(file3)

october_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1               143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2               305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3              1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4               277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
# ...             ...                       ...                       ...
# 30081          1054  2020-10-31 23:32:22.8650  2020-10-31 23:49:57.5320
# 30082           156  2020-10-31 23:33:22.7310  2020-10-31 23:35:59.4930
# 30083          1858  2020-10-31 23:37:01.7010  2020-11-01 00:07:59.7530
# 30084          1809  2020-10-31 23:37:46.1430  2020-11-01 00:07:55.2740
# 30085           395  2020-10-31 23:40:06.3530  2020-10-31 23:46:42.0640
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Check the datatypes
october_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
november_df.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                   int64
# gender                       int64
# dtype: object

# %%
# Tripduration as delta, start and end as datetimes
october_df['tripduration'] = pd.to_timedelta(october_df['tripduration'], unit='s')
october_df['starttime'] = pd.to_datetime(october_df['starttime'])
october_df['stoptime'] = pd.to_datetime(october_df['stoptime'])

november_df['tripduration'] = pd.to_timedelta(november_df['tripduration'], unit='s')
november_df['starttime'] = pd.to_datetime(november_df['starttime'])
november_df['stoptime'] = pd.to_datetime(november_df['stoptime'])

december_df['tripduration'] = pd.to_timedelta(december_df['tripduration'], unit='s')
december_df['starttime'] = pd.to_datetime(december_df['starttime'])
december_df['stoptime'] = pd.to_datetime(december_df['stoptime'])

# %%
# Check the datatypes again

#october_df.dtypes
#november_df.dtypes
december_df.dtypes
# Out:
# tripduration               timedelta64[ns]
# starttime                   datetime64[ns]
# stoptime                    datetime64[ns]
# start station id                     int64
# start station name                  object
# start station latitude             float64
# start station longitude            float64
# end station id                       int64
# end station name                    object
# end station latitude               float64
# end station longitude              float64
# bikeid                               int64
# usertype                            object
# birth year                           int64
# gender                               int64
# dtype: object

# %%
# Gender needs to be changed from int
# I looked it up, for gender it is (Zero=unknown; 1=male; 2=female);

gender_mapping = {0: 'Unknown', 1: 'Male', 2: 'Female'}
october_df['gender'] = october_df['gender'].replace(gender_mapping)
november_df['gender'] = november_df['gender'].replace(gender_mapping)
december_df['gender'] = december_df['gender'].replace(gender_mapping)

# %%
print(october_df['gender'])
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3           Male
# 4           Male
#           ...
# 30081    Unknown
# 30082       Male
# 30083       Male
# 30084       Male
# 30085       Male
# Name: gender, Length: 30086, dtype: object

# %%
october_df.to_csv('october_cleaned.csv', index=False)

# %%
november_df.to_csv('november_cleaned.csv', index=False)

# %%
december_df.to_csv('december_cleaned.csv', index=False)
